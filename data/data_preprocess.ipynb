# %% [markdown]
# # Data Preprocessing
#
# *Dataset*: https://huggingface.co/datasets/postbot/aeslc_kw
#
#
# Raw Huggingface dataset
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# data_preprocessing() -- clean email body and subject
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# Add columns:  *preprocessed_email_body* , *preprocessed_subject*
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# combine_body_subject() -- [optional] combine email body and subject
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# Add column:  *body_subject_combined*
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# add_instruction() -- [optional]  add instrution for subject generation task
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# Add column:  *email_with_instruction*
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# save preprocessed_dataset
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# = = = = = = = = = = = = = = = = =
# next notebook
# = = = = = = = = = = = = = = = = =
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# prepare_dataset()  -- tokenization and/or label creation
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# tokenized_dataset + tokenizer
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# = = = = = = = = = = = = = = = = =
# next script
# = = = = = = = = = = = = = = = = =
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# DataCollator
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# Trainer
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;↓
# Model

# %% [markdown]
# ### Setup

# %%
# import functions from data_preprocessing.py
import sys
import os
sys.path.append(os.path.abspath('..'))
from src.data_preprocessing import *

# %% [markdown]
# ### Load Dataset

# %%
ds = dataset_loader("postbot/aeslc_kw")

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['email_body', 'subject_line', 'clean_email', 'clean_email_keywords'],
#         num_rows: 14436
#     })
#     validation: Dataset({
#         features: ['email_body', 'subject_line', 'clean_email', 'clean_email_keywords'],
#         num_rows: 1960
#     })
#     test: Dataset({
#         features: ['email_body', 'subject_line', 'clean_email', 'clean_email_keywords'],
#         num_rows: 1906
#     })
# })

# %% [markdown]
# ### Data Preprocessing

# %%
# clean data
ds_preprocessed = ds.map(data_preprocessing)

# %%
# combine clean body and clean subject
ds_preprocessed = ds_preprocessed.map(combine_body_subject)
# Out:
# ...
# Map:   0%|          | 0/1906 [00:00<?, ? examples/s]

# %%
# add instruction to clean email body
ds_preprocessed = ds_preprocessed.map(add_instruction)
# Out:
# ...
# Map:   0%|          | 0/1906 [00:00<?, ? examples/s]

# %%
# save the preprocessed dataset to disk
ds_preprocessed.save_to_disk('preprocessed_dataset')
# Out:
# ...
# Saving the dataset (0/1 shards):   0%|          | 0/1906 [00:00<?, ? examples/s]
